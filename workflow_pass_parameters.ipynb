-- %%
%python
dbutils.widgets.text(name = 'test_value', defaultValue = '')
if dbutils.widgets.get('test_value') == 'Succeed':
     spark.sql("use catalog lakehouse_dev")
     spark.sql("use schema datasphere_test")
     spark.sql("create view succeed_view as select 1")
else:
    spark.sql("use catalog lakehouse_dev")
    spark.sql("use schema datasphere_test")
    spark.sql("create view failed_view as select 0")
